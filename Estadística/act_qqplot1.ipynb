# %% [markdown]
# #Pruebas de hipótesis
# #QQ-plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats

# %%
df = pd.read_excel('/content/drive/MyDrive/Tiempo_clientes.xlsx')

# %%
df.head()
# Out:
#    Número de cliente  Tiempo llegada
# 0                  1        1.637848
# 1                  2        1.416632
# 2                  3        0.011483
# 3                  4        1.191507
# 4                  5        0.640180

# %%
pd.isna(df).sum()
# Out:
# Número de cliente    0
# Tiempo llegada       0
# dtype: int64

# %%
figura = sm.qqplot(df['Tiempo llegada'], stats.expon, line='45')

# %%
figura = sm.qqplot(df['Tiempo llegada'], line='45')
